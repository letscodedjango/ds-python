# %%
# To access the .env data, we need to install python-dotenv package
# !pip install python-dotenv

# %%
from dotenv import load_dotenv, find_dotenv

# %%
# find .env automatically by walking through the directories until its found

# %%
dotenv_path = find_dotenv()
# Once we find the dotenv file lets load the dotenv entries as environmental variables
load_dotenv(dotenv_path)
# Out:
# True

# %%
# extracting environment variables using os.environ.get
import os
KAGGLE_USERNAME = os.environ.get("KAGGLE_USERNAME")
print(KAGGLE_USERNAME)
# Out:
# rajeshwar-sharma

# %%
# Lets extract the data from Kaggle website using Python code
import requests
from requests import session
import os
from dotenv import load_dotenv, find_dotenv

# %%
#Creating a payload to for post request to successfully login to kaggle
payload = {
    "action":'login',
    "username": os.environ.get("KAGGLE_USERNAME"),
    "password": os.environ.get("KAGGLE_PASSWORD") 
}

# url for train file 
url = "https://www.kaggle.com/c/titanic/download/train.csv"

# create session 
with session() as c:
    c.post("https://www.kaggle.com/account/login", data=payload)
    response = c.get(url)
    print(response)
    print(response.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Kaggle: Your Home for Data Science</title>
#     <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#     <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />
#     <meta name="turbolinks-cache-control" content="no-cache" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#     <meta name="theme-color" content="#008ABC" />
#     <script nonce="o7VT6Lt0ZptlJU&#x2B;e27UXdA==" type="text/javascript">
#         if ('serviceWorker' in navigator) {
#             navigator.serviceWorker.getRegistrations()
#                 .then(function(registrations) {
#                     for (let registration of registrations) {
#                         registration.unregister();
#                     }
# ...

# %%
# !pip install kaggle
# Out:
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.6-py3-none-any.whl size=72862 sha256=8a5d6ad5a5691a248f322e1d49696f377308b850e4089bce14a7e1bf7b0f9c5d
#   Stored in directory: c:\users\rajeshwar.sharma\appdata\local\pip\cache\wheels\79\40\57\49eee0c279b56aa3e06d10708dcfb53142240861b122303f2b
# Successfully built kaggle
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.9
#     Uninstalling urllib3-1.25.9:
#       Successfully uninstalled urllib3-1.25.9
# ...

# %%
import os
from dotenv import find_dotenv, load_dotenv
dotenv_path = find_dotenv()
# Once we find the dotenv file lets load the dotenv entries as environmental variables
load_dotenv(dotenv_path)
print(os.environ.get("KAGGLE_USERNAME"))
print(os.environ.get("KAGGLE_KEY"))
os.environ['KAGGLE_USERNAME'] = "rajeshwarsharma"
os.environ['KAGGLE_KEY'] = os.environ.get("KAGGLE_KEY")
# !kaggle competitions download -c titanic -p ../data/raw/
# Out:
# rajeshwarsharma
# b39cfada26d32907a29bf2197012380b
# ...
#   0%|          | 0.00/34.1k [00:00<?, ?B/s]
# 100%|##########| 34.1k/34.1k [00:00<00:00, 311kB/s]
# 100%|##########| 34.1k/34.1k [00:00<00:00, 303kB/s]

# %%
# !kaggle competitions download -c titanic -f train.csv
# Out:
# ...
#   0%|          | 0.00/59.8k [00:00<?, ?B/s]
# 100%|##########| 59.8k/59.8k [00:00<00:00, 7.55MB/s]

# %%
# This website helps to resolve 403 -Forbidden error - https://github.com/Kaggle/kaggle-api/issues/87
# !ls
# Out:
# 1.0-aka-extract-titanic-data.ipynb
# 2.0-rs-extract-titanic-data.ipynb
# titanic.zip
# train.csv

# %%
# !kaggle competitions download -c titanic -f test.csv
# Out:
# ...
#   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# 100%|##########| 28.0k/28.0k [00:00<00:00, 9.56MB/s]

# %%
# !ls
# Out:
# 1.0-aka-extract-titanic-data.ipynb
# 2.0-rs-extract-titanic-data.ipynb
# test.csv
# titanic.zip
# train.csv

# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib 
# !nbextension install
# Out:
# Please supply at least one subcommand: nbextension, nbextensions
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963399 sha256=edcc6877bf6c59944d4aa98b50990352a136a95f28f7ddc2440ee3eae2668c8b
#   Stored in directory: c:\users\rajeshwar.sharma\appdata\local\pip\cache\wheels\4d\ba\f4\b8c0941055519ebc0f27e85bfe2bb223f1a59a3b8bfc5c7515
# ...
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465829 sha256=b520f7a1f5ba382837c5648fe23731acf67c8af6a6ce3deaa5b6183f6a5d67d6
#   Stored in directory: c:\users\rajeshwar.sharma\appdata\local\pip\cache\wheels\e3\3a\b3\a709b437602c3807f079f0c35ccba3e1adf9af6f2e6b0ebfea
# Successfully built jupyter-latex-envs jupyter-nbextensions-configurator
# ...
# community-contributed spice for Jupyter Interactive Computing
#
# Subcommands
#
# -----------
#
#
#
# Subcommands are launched as `jupyter contrib cmd [args]`. For information on
# ...

# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# Out:
# ...
# [I 11:27:49 InstallContribNbextensionsApp] jupyter contrib nbextension install
# [I 11:27:49 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 11:27:49 InstallContribNbextensionsApp] Installing c:\users\rajeshwar.sharma\downloads\ds\ds-python\ds-py-pls-ak\venv\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 11:27:49 InstallContribNbextensionsApp] Making directory: C:\ProgramData\jupyter\nbextensions\addbefore\
# [I 11:27:49 InstallContribNbextensionsApp] Copying: c:\users\rajeshwar.sharma\downloads\ds\ds-python\ds-py-pls-ak\venv\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore\addbefore.yaml -> C:\ProgramData\jupyter\nbextensions\addbefore\addbefore.yaml
# ...

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\rajeshwar.sharma\.jupyter\custom &
# C:\Users\rajeshwar.sharma\AppData\Roaming\jupyter\nbextensions

# %%
# !jt -t chesterish -T -N -kl

# %%
# !jt -t chesterish -f inconsolata -fs 10 -nf inconsolata -nfs 10 -N -kl -cursw 5 -cursc r -cellw 95% -T

# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# Out:
# ...
# [I 11:42:34 InstallContribNbextensionsApp] jupyter contrib nbextension install
# [I 11:42:34 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 11:42:34 InstallContribNbextensionsApp] Installing c:\users\rajeshwar.sharma\downloads\ds\ds-python\ds-py-pls-ak\venv\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 11:42:34 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\addbefore.yaml
# [I 11:42:34 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\icon.png
# [I 11:42:34 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\main.js
# [I 11:42:34 InstallContribNbextensionsApp] Up to date: C:\ProgramData\jupyter\nbextensions\addbefore\readme.md
# [I 11:42:34 InstallContribNbextensionsApp] - Validating: ok
# ...

# %%
# lets define a function which helps to extract any shorts of data from Kaggle website
# Site to refere for Kaggle API - https://github.com/Kaggle/kaggle-api
import os
import kaggle
from dotenv import find_dotenv, load_dotenv
import sys

def extract_data(folder, filename, type=None):
    dotenv_file = find_dotenv()
    load_dotenv(dotenv_file)
    os.environ['KAGGLE_USERNAME']=os.environ.get('KAGGLE_USERNAME')
    os.environ['KAGGLE_KEY']=os.environ.get('KAGGLE_KEY')
    print(os.environ.get('KAGGLE_USERNAME') + ' ' + os.environ.get('KAGGLE_KEY'))
    raw_dir = os.path.join(os.pardir, 'data', 'raw')
    command = "kaggle competitions download -c"
    print(command)
    if type=='file':
        os.system(command + ' ' +folder+ ' -f ' + filename +' -p ' + raw_dir)   
    else:
        os.system(command + ' '+folder +' -p ' + raw_dir)

# %%
extract_data('titanic', 'train.csv')
# Out:
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 64B2-C0FF
#
#  Directory of C:\Users\rajeshwar.sharma\Downloads\DS\DS-Python\ds-py-pls-ak\letsds-titanic\notebooks
#
# 21-06-2020  14:49    <DIR>          .
# 21-06-2020  14:49    <DIR>          ..
# 20-06-2020  22:57                 0 .gitkeep
# 21-06-2020  00:04    <DIR>          .ipynb_checkpoints
# 21-06-2020  14:49           314,626 1.0-aka-extract-titanic-data.ipynb
# 21-06-2020  00:04               733 2.0-rs-extract-titanic-data.ipynb
# 21-06-2020  14:49            34,877 titanic.zip
#                4 File(s)        350,236 bytes
#                3 Dir(s)  918,332,637,184 bytes free

# %%
extract_data('titanic', 'train.csv', type='file')
# Out:
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c

# %%
extract_data('titanic', 'test.csv', type='file')
# Out:
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 64B2-C0FF
#
#  Directory of C:\Users\rajeshwar.sharma\Downloads\DS\DS-Python\ds-py-pls-ak\letsds-titanic\notebooks
#
# 21-06-2020  14:52    <DIR>          .
# 21-06-2020  14:52    <DIR>          ..
# 20-06-2020  22:57                 0 .gitkeep
# 21-06-2020  00:04    <DIR>          .ipynb_checkpoints
# 21-06-2020  14:51           314,514 1.0-aka-extract-titanic-data.ipynb
# 21-06-2020  00:04               733 2.0-rs-extract-titanic-data.ipynb
# 21-06-2020  14:52            28,629 test.csv
# 21-06-2020  14:49            34,877 titanic.zip
# 21-06-2020  14:52            61,194 train.csv
#                6 File(s)        439,947 bytes
#                3 Dir(s)  918,331,420,672 bytes free

# %%
# %ls ..\data\raw\
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 64B2-C0FF
#
#  Directory of C:\Users\rajeshwar.sharma\Downloads\DS\DS-Python\ds-py-pls-ak\letsds-titanic\data\raw
#
# 21-06-2020  15:32    <DIR>          .
# 21-06-2020  15:32    <DIR>          ..
# 20-06-2020  22:57                 0 .gitkeep
# 21-06-2020  15:32            28,629 test.csv
# 21-06-2020  15:31            34,877 titanic.zip
# 21-06-2020  15:32            61,194 train.csv
#                4 File(s)        124,700 bytes
#                2 Dir(s)  918,322,110,464 bytes free

# %%
# lets create a python script to perform all the operations in one go
extract_data_python_script_file = os.path.join(os.path.pardir, 'src', 'data', 'get_raw_data.py' )

# %%
# %%writefile $extract_data_python_script_file
# # To write the code from jupyter notebook to python file
#
# import os
# import kaggle
# from dotenv import find_dotenv, load_dotenv
# import sys
# import logging
#
#
# def extract_data(folder, filename=None, type=None):
#     logger = logging.getLogger(__name__)
#     logger.info("Getting raw data...")
#     log_fmt = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
#     logging.basicConfig(level=logging.INFO, format=log_fmt)
#     dotenv_file = find_dotenv()
#     load_dotenv(dotenv_file)
#     os.environ['KAGGLE_USERNAME']=os.environ.get('KAGGLE_USERNAME')
#     os.environ['KAGGLE_KEY']=os.environ.get('KAGGLE_KEY')
#     print(os.environ.get('KAGGLE_USERNAME') + ' ' + os.environ.get('KAGGLE_KEY'))
#     raw_dir = os.path.join(os.pardir, 'data', 'raw')
#     command = "kaggle competitions download -c"
#     print(command)
#     if type=='file':
#         logger.info("Downloading the dataset from kaggle ...")
#         os.system(command + ' ' +folder+ ' -f ' + filename +' -p ' + raw_dir)
#     else:
#         logger.info("Downloading the dataset from kaggle ...")
#         os.system(command + ' '+folder +' -p ' + raw_dir)
#
# if __name__ == '__main__':
#     extract_data('titanic', 'train.csv', type='file')
#     extract_data('titanic', 'test.csv', type='file')
#     extract_data('titanic')
# Out:
# Overwriting ..\src\data\get_raw_data.py

# %%
print(extract_data_python_script_file)
# !python $extract_data_python_script_file
# Out:
# ..\src\data\get_raw_data.py
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...
# 2020-06-21 22:48:21,114 - __main__ - INFO - Downloading the dataset from kaggle ...
# 2020-06-21 22:48:23,134 - __main__ - INFO - Getting raw data...
# 2020-06-21 22:48:23,135 - __main__ - INFO - Downloading the dataset from kaggle ...
#
#   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# 100%|##########| 28.0k/28.0k [00:00<00:00, 7.22MB/s]
# 2020-06-21 22:48:25,638 - __main__ - INFO - Getting raw data...
# 2020-06-21 22:48:25,640 - __main__ - INFO - Downloading the dataset from kaggle ...
#
#   0%|          | 0.00/34.1k [00:00<?, ?B/s]
# 100%|##########| 34.1k/34.1k [00:00<00:00, 8.73MB/s]
# ...
#
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c
# rajeshwarsharma b39cfada26d32907a29bf2197012380b
# kaggle competitions download -c
